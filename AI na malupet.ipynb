# %%
import numpy as numpy
import time

# %%
class AI:
    def __init__(self, input):
        self.input = input
    
    def think(self):
        print("Thinking...")
        time.sleep(2)
        print("Still thinking...")
        time.sleep(1)
        print("Plugging data to Reinforced Neural Network...")
        time.sleep(3)
        print("Solving eigenvalues and eigenvectors...")
        time.sleep(1.5)
        print("Your number is:")
        time.sleep(0.5)
        return 67

# %%
user_input = int(input("Enter a number: "))
ai = AI(user_input)
print(ai.think())
# Out:
# Thinking...
# Still thinking...
# Plugging data to Reinforced Neural Network...
# Solving eigenvalues and eigenvectors...
# Your number is:
# 67
